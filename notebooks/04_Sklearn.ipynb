# %%
import sys
sys.path.append("../src")

# %%
from data_loader import load_data
from preprocessing import *
from linear_sklearn import *
from evaluate import *

# %%
df = load_data()
train_set, test_set = split_data(df)
X_train, X_test, y_train, y_test = prepare_data(train_set, test_set)

# %%
model = train_linear_regression(X_train, y_train)

# %%
pred = predict(model, X_test)

# %%
print_regression_metrics(y_test, pred)

# %%
plot_prediction(y_test, pred)

# %% [markdown]
# Sklearn Linear Regression cho kết quả ổn định và nhanh hơn so với cài đặt thủ công.
