# %% [markdown]
# # California Housing Price Prediction
#
# ## 1. Exploratory Data Analysis (EDA)
#
# Mục tiêu:
#
# - Load dữ liệu
# - Quan sát dữ liệu
# - Thống kê mô tả
# - Kiểm tra missing value
# - Vẽ histogram
# - Vẽ heatmap
# - Vẽ boxplot

# %%
import sys
import os

sys.path.append("../src")

# %%
from data_loader import load_data
from visualization import *

import warnings
warnings.filterwarnings("ignore")

# %%
df = load_data()

df.head()

# %%
df.info()

# %%
df.describe()

# %%
df.isnull().sum()

# %%
plot_histograms(df)

# %%
plot_heatmap(df)

# %%
plot_boxplots(df)

# %% [markdown]
# ### Nhận xét
#
# - Median Income có tương quan mạnh nhất
# - House Value phân bố lệch phải
# - Một số feature có outlier
